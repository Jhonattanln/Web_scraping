# %% [markdown]
# #### Web scraping para risco brasil

# %%
### Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
url = 'http://www.ipeadata.gov.br/ExibeSerie.aspx?serid=40940&module=M'

# %%
html = pd.read_html(url, match='EMBI ')

# %%
df = html[1]
df.columns = df.iloc[0]

# %%
df.drop(0, inplace=True)
df['Data'] = pd.to_datetime(df['Data'], format='%d/%m/%Y')

# %%
#df.set_index('Data', inplace=True)

# %%
df.rename(columns={'EMBI + Risco-Brasil': 'Risco país'}, inplace=True)
df['Risco país'] = df['Risco país'].str.replace('.', '')
df['Risco país'] = pd.to_numeric(df['Risco país'], errors='coerce')
# Out:
# C:\Users\Jhona\AppData\Local\Temp/ipykernel_6396/870452181.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Risco país'] = df['Risco país'].str.replace('.', '')

# %%
fig = px.line(df, x='Data', y='Risco país', title='Risco país')
fig.update_layout(xaxis_title='Data', yaxis_title='Risco país',)
fig.show()

# %%
df.head(10)
# Out:
# 0        Data  Risco país
# 1  2022-07-18         364
# 2  2022-07-15         376
# 3  2022-07-13         376
# 4  2022-07-12         367
# 5  2022-07-11         359
# 6  2022-07-08         349
# 7  2022-07-07         352
# 8  2022-07-06         357
# 9  2022-07-05         369
# 10 2022-07-04         362
